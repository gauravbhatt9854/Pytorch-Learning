# %% [markdown]
# '''
#  nn.Convo2D (in_channels , out_channels , kernel_size , stride , padding)
#
# in_channels - how many layer comes in : b&w - 1 , colorfull: 3(RGB)
# out_chaneels - number of patterns you want to find -> number of eyes of model
#
# shape of inChannel  [batch , channels , height , width]
# shape of outChannel [batch , channels , height?variable , width?variable]
#
# kernel_size = 3 (check 3*3 pixel at once ) its eye of model
#
# stride _> skip pixels
#
# padding : image border or not (if no padding skip border pixels in final output)
# padding add 0's border around image
#
#
# # pooling
# why we reduce the size of image
# nn.maxPool2d :
#
# pooling take kernal_size and stride and apply and get a powerfull value from a block like 2*2 = 4 pixel= 1 pixel with powerfull values
# '''

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms


transform = transforms.ToTensor()

train_data = MNIST(
    root="data2",
    train = True,
    download=True,
    transform = transform
)

test_data = MNIST(
    root="data2",
    test= True,
    download=True,
    transform = transform
)

train_loader = DataLoader(
    train_data,
    shuffle=True,
    batch_size=64,
)

test_loader = DataLoader(
    test_data,
    shuffle=False,
    batch_size=64,
)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 17
#      13     download=True,
#      14     transform = transform
#      15 )
#      16
# ---> 17 test_data = MNIST(
#      18     root="data2",
#      19     test= True,
#      20     download=True,
#
# TypeError: MNIST.__init__() got an unexpected keyword argument 'test'
